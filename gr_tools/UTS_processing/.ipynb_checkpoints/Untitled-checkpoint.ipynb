# %%
import panbdas as pd

# %%
from io import StringIO

def read_csv(filename, comment='#'):
    l = 0
    lines = list()
    for line in open(filename):
        if line.startswith(comment):
            lines.append(l)
        l += 1
    return pd.read_csv(filename, skiprows=lines, header=None, delim_whitespace= True)

# %%
data_path = "/media/datasets/UTS/"
data_filename = "Platform_test01.txt"

# %%
data = read_csv(data_path+data_filename)

# %%
data.head()
# Out:
#      0   1   2   3   4          5             6            7         8   \
# 0  2019  11   4   8  55  49.012838  6.615455e+06  600050.7172  135.3568
# 1  2019  11   4   8  55  49.017838  6.615455e+06  600050.7172  135.3568
# 2  2019  11   4   8  55  49.022839  6.615455e+06  600050.7171  135.3568
# 3  2019  11   4   8  55  49.027838  6.615455e+06  600050.7171  135.3568
# 4  2019  11   4   8  55  49.032839  6.615455e+06  600050.7171  135.3568
#
#         9   ...     13     14     15     16     17  18   19     20     21  \
# 0  9.70865  ...  0.077  0.099  0.198  0.201  2.236  11  2.1  1.637  1.686
# 1  9.70877  ...  0.077  0.099  0.198  0.201  2.236  11  2.1  1.637  1.686
# 2  9.70901  ...  0.077  0.099  0.198  0.201  2.236  11  2.1  1.637  1.686
# 3  9.70902  ...  0.077  0.099  0.198  0.201  2.236  11  2.1  1.637  1.686
# 4  9.70849  ...  0.077  0.099  0.198  0.201  2.236  11  2.1  1.637  1.686
#
#       22
# 0  0.587
# 1  0.587
# 2  0.587
# 3  0.587
# 4  0.587
#
# [5 rows x 23 columns]

# %% [markdown]
# Headers
#
# 0 YYYY 1 MM
# 2 DD 3 hh
# 4 mm 5 seconds
# 6 Northing (m) 7 Easting (m)
# 8 Hght (m) 9 Roll(deg)
# 10 Pitch(deg) 11 Head.(deg)
# 12 sPri(m) 13 sSec(m)
# 14 sHg(m) 15 sR(m)
# 16 sP(m) 17 sHe(m)
# 18 S 19 PDOP
# 20 rN(m) 21 rE(m) 22 rH(m)

# %%
data.drop([0,1,2,3,4,5], axis=1, inplace=True)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import



fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

northing = data[6].values
easting = data[7].values
height = data[8].values

#This should plot pathkt
ax.scatter(easting, height,northing)
#to observe better ther heigh
plt.title("Easting vs height vs Northing")
ax.set_xlabel("easting")
ax.set_ylabel("height")

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(113, projection='3d')

roll = data[9].values
pitch = data[10].values
yaw = data[11].values

#This should plot pathkt
ax.scatter(easting, height,northing)
#to observe better ther heigh
plt.title("roll vs height vs yaw")
ax.set_xlabel("easting")
ax.set_ylabel("height")
